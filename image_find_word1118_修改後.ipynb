# %% [markdown]
# <a href="https://colab.research.google.com/github/MeldaChen/Group-4/blob/main/image_find_word1118_%E4%BF%AE%E6%94%B9%E5%BE%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
from PIL import ImageFont, ImageDraw, Image


m1 = cv2.imread('D007.jpg', 1)

copy = m1.copy()

erode = cv2.erode(copy, np.ones((30, 30))) #抓字

# th, thres = cv2.threshold(erode, 110, 255, cv2.THRESH_BINARY) #二值化去背



gray = cv2.cvtColor(copy, cv2.COLOR_BGR2GRAY) #轉灰階

blur = cv2.GaussianBlur(gray,(5,5),0)   #模糊化

# th, thres_2 = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU) #二值化去背again

canny = cv2.Canny(blur, 70, 210)

th, canny = cv2.threshold(canny, 10, 255, cv2.THRESH_BINARY)

morph = cv2.morphologyEx(canny, cv2.MORPH_GRADIENT, np.ones((10, 10))) 
p, t = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
 


for i in range(0, len(p), 1): 
    x, y, w, h = cv2.boundingRect(p[i]) 
    cv2.rectangle(m1, (x,y), (x+w, y+h), (0, 0, 255), 2)
    cv2_imshow(m1[y : y + h, x : x + w]) #只放框起來的地方

n = max(w,h)
compare_word = np.full((n, n, 3), (255, 0, 0), np.uint8)  #之後底色再改為(255, 255, 255)，不然看不出來
compare_word = Image.fromarray(compare_word)
ImageDraw.Draw(compare_word).text((5,5),
            ("字"), #要換成練習的字
            (0, 0, 0),
            ImageFont.truetype("ThePeakFontBeta_V0_101.ttf", n)  #要上傳字體
)
compare_word = np.array(compare_word)

cv2_imshow(compare_word)

cv2_imshow(m1)
print("---------")
# cv2_imshow(thres)
# print("---------")
# cv2_imshow(thres_2)
# print("---------")
# cv2_imshow(m4)
# print("---------")
# Out:
# <PIL.Image.Image image mode=RGB size=181x176 at 0x7FAC2218D210>
# <PIL.Image.Image image mode=RGB size=181x181 at 0x7FAC2218D150>
# <PIL.Image.Image image mode=RGB size=1108x1477 at 0x7FAC2218D110>
# ---------

# %%
# 生成相同大小的印刷字圖像，已合併到上一格

import cv2
import numpy as np
import IPython.display as dp
from google.colab.patches import cv2_imshow
from PIL import ImageFont, ImageDraw, Image

compare_word = np.full((80, 80, 3), (255, 0, 0), np.uint8)  #之後底色再改為(255, 255, 255)
compare_word = Image.fromarray(compare_word)
ImageDraw.Draw(compare_word).text((5,5),
            ("字"), 
            (0, 0, 0),
            ImageFont.truetype("ThePeakFontBeta_V0_101.ttf", 70)  #要上傳字體
)
compare_word = np.array(compare_word)

cv2_imshow(compare_word)
# Out:
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7F63E8BF2090>

# %%
#Enos老師的影像辨識碼

@handler.add(MessageEvent, message=ImageMessage)
def handle_message(event):
    message_id = event.message.id
    message_content = line_bot_api.get_message_content(message_id)
        
    b = b''
    for chunk in message_content.iter_content():
        b += chunk
    img = Image.open(io.BytesIO(b))
    r = classify(img)
    line_bot_api.reply_message(
        event.reply_token,
        TextSendMessage(text=r))


def classify(img):
    img = ImageOps.fit(img, model.input.shape[1:3])
    prediction = model.predict(np.expand_dims(img, axis=0)/255.)
    p = np.argmax(prediction)
    with open(label, encoding='utf-8') as f:
        labels = f.read().split()
    return labels[p] if 0 <= p < len(labels) else 'unknown'
